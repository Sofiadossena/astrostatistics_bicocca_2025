# %%
import numpy as np  
import matplotlib.pyplot as plt 
import random
import sklearn 
from random import sample
from sklearn.neighbors import KernelDensity
import scipy
import scipy.integrate as integrate
import astropy.visualization.hist

today=0 #cloudy day 
cloudy_counts=0
sunny_counts=0
Ps=[]
Pc=[]

N=100000

for i in range(N):
    if today ==0:
        p=np.random.uniform(0,1)
        if p<=0.5:
            today=0
        else :
            today=1
    else :
        p=np.random.uniform(0,1)
        if p<=0.1:
            today=0
        else :
            today=1
    if today ==0:
        cloudy_counts+=1
    else :
        sunny_counts+=1
    
    Ps.append(sunny_counts/(i+1))
    Pc.append(cloudy_counts/(i+1))

Psunny= sunny_counts/N
Pcloudy= cloudy_counts/N

x=np.linspace(0,N,N)
plt.plot(x,Ps)
plt.show()
plt.plot(x,Pc)
plt.show()
